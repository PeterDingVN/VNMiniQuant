# %%
from pathlib import Path
import sys
root = Path.cwd().parent
sys.path.append(str(root))

from ExeCore.exe import AlphaCore
alpha = AlphaCore()
# Out:
# [WARNING] Trading View's limit on INTRADAY DATA for ACB can cause unexpected error!
# [WARNING] Trading View's limit on INTRADAY DATA for VCI can cause unexpected error!
# [CACHE] Loaded VN:ACB_15m sucessfully
# [CACHE] Loaded VCI_5m sucessfully
#
# Successfully scraped 2/2 symbol

# %%
# Data
data_list = alpha.generate_data()
vci = data_list['VCI_5m']
cts = data_list['ACB_15m']

# %%
# Train Alpha
param_range = {
    "don_lookback": (10, 100),
    "ema_lookback": (10, 200),
    "atr_lookback": (5, 100),
    "long_atr_mult": (0.5, 7.0, 0.05),
    "short_atr_mult": (0.5, 7.0, 0.05),
    }

alpha.train_ta(cts, param_range=param_range, opt_metric="sharpe*return**2", n_trials=20)
# Out:
# [WARNING] Trading View's limit on INTRADAY DATA for ACB can cause unexpected error!
# [WARNING] Trading View's limit on INTRADAY DATA for VCI can cause unexpected error!
# [CACHE] Loaded VN:ACB_15m sucessfully
# [I 2026-07-12 16:23:46,053] A new study created in memory with name: no-name-bb7ea376-69e1-4835-99af-a52280d80121
# [CACHE] Loaded VCI_5m sucessfully
#
# Successfully scraped 2/2 symbol
# [W 2026-07-12 16:23:46,392] Trial 0 failed with parameters: {'don_lookback': 74, 'ema_lookback': 99, 'atr_lookback': 29, 'long_atr_mult': 4.45, 'short_atr_mult': 1.4} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:46,394] Trial 0 failed with value np.float64(nan).
# [W 2026-07-12 16:23:46,729] Trial 1 failed with parameters: {'don_lookback': 37, 'ema_lookback': 60, 'atr_lookback': 37, 'long_atr_mult': 2.0, 'short_atr_mult': 1.6500000000000001} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:46,731] Trial 1 failed with value np.float64(nan).
# [W 2026-07-12 16:23:47,043] Trial 2 failed with parameters: {'don_lookback': 41, 'ema_lookback': 111, 'atr_lookback': 36, 'long_atr_mult': 2.5500000000000003, 'short_atr_mult': 6.45} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:47,045] Trial 2 failed with value np.float64(nan).
# [W 2026-07-12 16:23:47,365] Trial 3 failed with parameters: {'don_lookback': 97, 'ema_lookback': 89, 'atr_lookback': 26, 'long_atr_mult': 1.35, 'short_atr_mult': 1.7000000000000002} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:47,366] Trial 3 failed with value np.float64(nan).
# [W 2026-07-12 16:23:47,690] Trial 4 failed with parameters: {'don_lookback': 14, 'ema_lookback': 136, 'atr_lookback': 23, 'long_atr_mult': 0.5, 'short_atr_mult': 6.300000000000001} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:47,692] Trial 4 failed with value np.float64(nan).
# [W 2026-07-12 16:23:48,011] Trial 5 failed with parameters: {'don_lookback': 92, 'ema_lookback': 117, 'atr_lookback': 15, 'long_atr_mult': 1.15, 'short_atr_mult': 2.25} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:48,012] Trial 5 failed with value np.float64(nan).
# [I 2026-07-12 16:23:48,330] Trial 6 finished with value: -3697.219718217908 and parameters: {'don_lookback': 21, 'ema_lookback': 10, 'atr_lookback': 90, 'long_atr_mult': 2.4000000000000004, 'short_atr_mult': 7.0}. Best is trial 6 with value: -3697.219718217908.
# [W 2026-07-12 16:23:48,693] Trial 7 failed with parameters: {'don_lookback': 66, 'ema_lookback': 32, 'atr_lookback': 32, 'long_atr_mult': 5.550000000000001, 'short_atr_mult': 6.2} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:48,695] Trial 7 failed with value np.float64(nan).
# [W 2026-07-12 16:23:48,986] Trial 8 failed with parameters: {'don_lookback': 67, 'ema_lookback': 119, 'atr_lookback': 75, 'long_atr_mult': 4.300000000000001, 'short_atr_mult': 0.65} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:48,988] Trial 8 failed with value np.float64(nan).
# [W 2026-07-12 16:23:49,291] Trial 9 failed with parameters: {'don_lookback': 32, 'ema_lookback': 52, 'atr_lookback': 55, 'long_atr_mult': 6.2, 'short_atr_mult': 2.8000000000000003} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:49,293] Trial 9 failed with value np.float64(nan).
# [W 2026-07-12 16:23:49,652] Trial 10 failed with parameters: {'don_lookback': 89, 'ema_lookback': 67, 'atr_lookback': 53, 'long_atr_mult': 5.5, 'short_atr_mult': 0.8500000000000001} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:49,654] Trial 10 failed with value np.float64(nan).
# [W 2026-07-12 16:23:49,973] Trial 11 failed with parameters: {'don_lookback': 69, 'ema_lookback': 103, 'atr_lookback': 54, 'long_atr_mult': 5.300000000000001, 'short_atr_mult': 3.75} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:49,975] Trial 11 failed with value np.float64(nan).
# [W 2026-07-12 16:23:50,300] Trial 12 failed with parameters: {'don_lookback': 53, 'ema_lookback': 104, 'atr_lookback': 6, 'long_atr_mult': 6.9, 'short_atr_mult': 6.5} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:50,301] Trial 12 failed with value np.float64(nan).
# [W 2026-07-12 16:23:50,622] Trial 13 failed with parameters: {'don_lookback': 73, 'ema_lookback': 75, 'atr_lookback': 18, 'long_atr_mult': 3.5500000000000003, 'short_atr_mult': 4.8500000000000005} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:50,623] Trial 13 failed with value np.float64(nan).
# [W 2026-07-12 16:23:50,916] Trial 14 failed with parameters: {'don_lookback': 51, 'ema_lookback': 88, 'atr_lookback': 23, 'long_atr_mult': 4.15, 'short_atr_mult': 2.85} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:50,918] Trial 14 failed with value np.float64(nan).
# [W 2026-07-12 16:23:51,250] Trial 15 failed with parameters: {'don_lookback': 36, 'ema_lookback': 187, 'atr_lookback': 23, 'long_atr_mult': 5.9, 'short_atr_mult': 4.6000000000000005} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:51,252] Trial 15 failed with value np.float64(nan).
# [W 2026-07-12 16:23:51,566] Trial 16 failed with parameters: {'don_lookback': 34, 'ema_lookback': 26, 'atr_lookback': 59, 'long_atr_mult': 7.0, 'short_atr_mult': 1.75} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:51,568] Trial 16 failed with value np.float64(nan).
# [W 2026-07-12 16:23:51,888] Trial 17 failed with parameters: {'don_lookback': 49, 'ema_lookback': 73, 'atr_lookback': 82, 'long_atr_mult': 2.4000000000000004, 'short_atr_mult': 1.6500000000000001} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:51,892] Trial 17 failed with value np.float64(nan).
# [W 2026-07-12 16:23:52,206] Trial 18 failed with parameters: {'don_lookback': 74, 'ema_lookback': 83, 'atr_lookback': 96, 'long_atr_mult': 1.9000000000000001, 'short_atr_mult': 1.55} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:52,208] Trial 18 failed with value np.float64(nan).
# [W 2026-07-12 16:23:52,534] Trial 19 failed with parameters: {'don_lookback': 69, 'ema_lookback': 181, 'atr_lookback': 71, 'long_atr_mult': 5.0, 'short_atr_mult': 2.0} because of the following error: The value nan is not acceptable.
# [W 2026-07-12 16:23:52,536] Trial 19 failed with value np.float64(nan).

# %%
# Backtest
RED = "\033[31m"
RESET = "\033[0m"
print(f"{RED}AFTER OPTUNA PLEASE RUN CELL 1 AGAIN TO SEE RESULT AFTER OPTIMIZATION{RESET}")

alpha.backtest_ta(cts)
# Out:
# AFTER OPTUNA PLEASE RUN CELL 1 AGAIN TO SEE RESULT AFTER OPTIMIZATION
# [WARNING] Trading View's limit on INTRADAY DATA for ACB can cause unexpected error!
# [WARNING] Trading View's limit on INTRADAY DATA for VCI can cause unexpected error!
# [CACHE] Loaded VN:ACB_15m sucessfully
# [CACHE] Loaded VCI_5m sucessfully
#
# Successfully scraped 2/2 symbol
#
# *****************  TRAINING RESULT *****************
#
# ======================================================
#              Financial Backtest Vn Stock
# ======================================================
#     Initial capital: 100,000,000.00
#      Ending capital: 92,262,122.00
#              Sharpe: -1.93
#             Sortino: -2.48
#              Calmar: -2.15
#                 MDD: 11,457,230.54 (11.46%); Time: 2025-10-10 10:45:00 -> 2025-12-08 13:00:00
#        Total Profit: -7,737,878.00
#    Margin per Trade: -92.51 bps
#        Total Return: -7.12%
#     Return per year: -24.59%
#                CAGR: -22.52%
#        Hitrate Long: 28.17%
#       Hitrate Short: 0.00%
#       Total Hitrate: 28.17%
#         Longest Win: 2 days
#        Longest Loss: 4 days
#       Trade per Day: 0.05
#         Long Trades: 4
#        Short Trades: 0
#
# *****************  TEST RESULT *****************
#
# ======================================================
#              Financial Backtest Vn Stock
# ======================================================
#     Initial capital: 100,000,000.00
#      Ending capital: 95,147,976.03
#              Sharpe: -8.68
#             Sortino: -17.58
#              Calmar: -19.15
#                 MDD: 4,852,023.97 (4.85%); Time: 2025-12-12 14:45:00 -> 2025-12-31 14:00:00
#        Total Profit: -4,852,023.97
#    Margin per Trade: -160.62 bps
#        Total Return: -4.79%
#     Return per year: -92.91%
#                CAGR: -61.41%
#        Hitrate Long: 22.58%
#       Hitrate Short: 0.00%
#       Total Hitrate: 22.58%
#         Longest Win: 1 days
#        Longest Loss: 2 days
#       Trade per Day: 0.15
#         Long Trades: 2
#        Short Trades: 0
